# %%
# !pip install opencv-python
# !pip install face-recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=8e650a05932f2efcbc1c3f6d6d5a40a0c1ca6ffdefd28804632ea513c76146e3
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %% [markdown]
# ## Because I use Google Colab, I implemented this code to upload the images.

# %%
# IF you upload form google colab
from google.colab import files

# Upload image files
uploaded = files.upload()

# Access the uploaded files
for filename, file_content in uploaded.items():
    # Save the file
    with open(filename, 'wb') as f:
        f.write(file_content)
    print(f"File '{filename}' uploaded successfully.")
# Out:
#      <input type="file" id="files-9c9dc2ba-1283-442d-b2e6-13face88923e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c9dc2ba-1283-442d-b2e6-13face88923e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # If you implement data from jyptyer

# %%
# import os

# # Define the path to the 'data' folder
# data_folder_path = 'data/'

# # List all files in the 'data' folder
# data_files = os.listdir(data_folder_path)

# # Process each file in the 'data' folder
# for filename in data_files:
#     file_path = os.path.join(data_folder_path, filename)
#     if os.path.isfile(file_path):
#         with open(file_path, 'rb') as f:
#             file_content = f.read()
#             # Process the file_content as needed
#         print(f"File '{filename}' accessed and processed.")

# %% [markdown]
# # The data about the Dunder Mifflin Paper Company Team ![c8d29efc-8433-4969-b675-e550ce3922b0-Ryan_then.webp](data:image/webp;base64,...)

# %%
import cv2
import face_recognition

def find_face_encodings(image_path):

    # Read the image
    image = cv2.imread(image_path)

    # Get face encodings from the image
    face_encodings = face_recognition.face_encodings(image)

    # Return the face encodings
    return face_encodings[0] if face_encodings else None

# %%
# getting face encodings for first image
image_1 = find_face_encodings("Michael.jpg")
# getting face encodings for second image
image_2  = find_face_encodings("Michael2.jpg")

# %%
if image_1 is not None and image_2 is not None:
    # Compare the faces
    is_same = face_recognition.compare_faces([image_1], image_2)[0]

    if is_same:
        # Calculate the distance between the faces
        distance = face_recognition.face_distance([image_1], image_2)
        distance = round(distance[0] * 100)

        # Calculate the accuracy level
        accuracy = 100 - distance

        print("The images are the same.")
        print(f"Accuracy Level: {accuracy:.2f}%")
    else:
        print("The images are not the same.")
else:
    print("Failed to extract face encodings from one or both images.")
# Out:
# The images are the same.
# Accuracy Level: 62.00%
